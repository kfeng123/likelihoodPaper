# %%
import numpy as np
import matplotlib.pyplot as plt
x = list(range(5))
y = [i**2 for i in x]
plt.plot(x,y)
plt.show()

# %%
N = 200
alpha = 0.3
X = (1-alpha) * np.random.normal(0,1, N) + alpha * np.random.normal(1, 1, N)
plt.hist(X, bins = 50)
plt.show()
